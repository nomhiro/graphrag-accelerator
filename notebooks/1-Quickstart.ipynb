# %% [markdown]
# # GraphRAG Quickstart

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages, not part of the Python Standard Library, to run the notebook

# %%
! pip install devtools python-magic requests tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: devtools in /home/vscode/.local/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: python-magic in /home/vscode/.local/lib/python3.10/site-packages (0.4.27)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.4.1)
# Requirement already satisfied: pygments>=2.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.18.0)
# Requirement already satisfied: executing>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.17.0)

# %%
import getpass
import json
import time
from pathlib import Path

import magic
import requests
from devtools import pprint
from tqdm import tqdm

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in the notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
ocp_apim_subscription_key = getpass.getpass(
    "ここにAPI ManagementのAPI subscription keyを設定"
)

"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = "../data"
storage_name = "data"
index_name = "test-all-01"
endpoint = "https://apim-uugxkaopsbxne.azure-api.net"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ## Upload Files
#
# For a demonstration of how to index data in graphrag, we first need to ingest a few files into graphrag.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must have utf-8 encoding.
    storage_name - a unique name for the Azure storage blob container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage blob container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response


response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
#   0%|          | 0/168 [00:00<?, ?it/s]
# 100%|██████████| 168/168 [00:05<00:00, 31.61it/s]
# <Response [200]>

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded, we can construct a knowledge graph by building a search index.

# %%
def build_index(
    storage_name: str,
    index_name: str,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    request = {"storage_name": storage_name, "index_name": index_name}
    return requests.post(url, params=request, headers=headers)


response = build_index(storage_name=storage_name, index_name=index_name)
print(response)
if response.ok:
    print(response.text)
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# <Response [202]>
# {"detail":"Index 'test-01' already exists and has not finished building."}

# %% [markdown]
# ### Check status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


response = index_status(index_name)
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'test-01',
#     'storage_name': 'data',
#     'status': 'complete',
#     'percent_complete': 100.0,
#     'progress': '16 out of 16 workflows completed successfully.',
# }

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
# a helper function to parse out the result from a query response
def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Print response['result'] value and return context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response

# %% [markdown]
# ### Global Query
#
# Global queries are resource-intensive, but provide good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time


def global_search(
    index_name: str | list[str], query: str, community_level: int
) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    # optional parameter: community level to query the graph at (default for global query = 1)
    request = {
        "index_name": index_name,
        "query": query,
        "community_level": community_level,
    }
    return requests.post(url, json=request, headers=headers)


# perform a global query
global_response = global_search(
    index_name=index_name,
    query="このデータに見られる主なトピックをまとめて",
    community_level=1,
)
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# ## 主なトピックの概要
#
# このデータセットには、住宅エリアの建設特徴、アフターサービスの役割、寒冷地での特有の課題、換気システムのメンテナンス、そしてガス給湯器の設置と保守に関する情報が含まれています。以下に各トピックの詳細を示します。
#
# ### 住宅エリアの建設特徴
#
# ハイムとデシオGTの住宅エリアは、石膏ボードを使用した壁や天井などの独自の建設特徴を持っています。これらの材料は、構造の完全性と安全性を確保するために特定の建設およびメンテナンスガイドラインが必要です [Data: Reports (4)]。
#
# ### アフターサービスの役割
#
# アフターセールスサービス部門は、設置や構造変更に関するサポートと相談を提供する重要な役割を果たしています。これには、ガス給湯器や床の補強などのシステムの安全性と効率性を確保することが含まれます [Data: Reports (9)]。
#
# ### 寒冷地での特有の課題
#
# 北海道のような寒冷地では、水道管、メーター、ヒーターの凍結を防ぐための特定の対策が必要です。これにより、機能性を維持し、損傷を防ぐことができます [Data: Reports (1)]。
#
# ### 換気システムのメンテナンス
#
# 第1種換気システム、またはエアファクトリーは、ハイムやデシオGTのような住宅エリアで使用される包括的な換気システムです。空気の質と快適さを確保するために、フィルターなどのコンポーネントの定期的なメンテナンスが必要です [Data: Reports (8)]。
#
# ### ガス給湯器の設置と保守
#
# 設置業者は、ガス給湯器の設置と保守を担当しており、アフターセールスサービス部門と緊密に連携して効率的な運用を確保し、故障に対処します [Data: Reports (11)]。
#
# これらのトピックは、住宅の安全性、効率性、快適性を確保するための重要な要素を示しています。
# CPU times: user 23.3 ms, sys: 1.41 ms, total: 24.7 ms
# Wall time: 13.8 s
# {'reports': [{'id': '4',
#    'title': 'ハイム and デシオGT Residential Areas',
#    'occurrence weight': 1.0,
#    'content': "# ハイム and デシオGT Residential Areas\n\nThe community is centered around the residential areas of ハイム and デシオGT, which are characterized by specific construction and maintenance requirements. These areas utilize gypsum board construction and have detailed guidelines for ventilation systems and air conditioner installations, involving entities like ツーユー and エアコン室内機.\n\n## Unique construction features of ハイム and デシオGT\n\nBoth ハイム and デシオGT are residential areas with unique construction features that involve the use of gypsum board for walls and ceilings. This construction method requires specific attention to the positioning of wood studs and the fixing of nails or screws to ensure structural integrity and safety. The use of gypsum board necessitates adherence to specific guidelines to maintain the durability and safety of the structures [Data: Entities (27, 28); Relationships (39, 43, 44, 40)].\n\n## Ventilation systems in residential areas\n\nThe residential areas of ハイム and デシオGT are equipped with specific ventilation systems to ensure proper air circulation and comfort. The 第1種換気システム is used in both areas, highlighting the importance of maintaining air quality and comfort for residents. These systems are integral to the living environment and require regular maintenance as outlined in the applicable guides [Data: Relationships (45, 42)].\n\n## Role of ツーユー in construction\n\nツーユー plays a significant role in the construction of residential areas by providing materials for wall construction and air conditioner installations. It is characterized by a wood stud position width of 455mm and is used in conjunction with gypsum board, which requires specific fixing methods. This highlights the versatility and importance of ツーユー in ensuring the structural integrity and functionality of residential constructions [Data: Entities (42); Relationships (58, 59, 60, 61)].\n\n## Air conditioner installation requirements\n\nThe installation of air conditioners in these residential areas involves specific materials and methods. The indoor unit, エアコン室内機, requires particular installation techniques as illustrated in diagrams A and B. Materials like デコスケ and ツーユー are used to ensure proper installation and functionality. The after-sales service department provides support for these installations, emphasizing the technical complexity and importance of following precise guidelines [Data: Entities (64); Relationships (83, 61, 92, 93, 94)].\n\n## Maintenance and safety guidelines\n\nThe residential areas of ハイム and デシオGT have detailed maintenance and safety guidelines to ensure a comfortable and safe living environment. These guidelines cover aspects such as load limits for ceilings and walls, and the maintenance of ventilation systems. Adhering to these guidelines is crucial for maintaining the structural integrity and safety of the residential areas, highlighting the community's focus on quality and safety [Data: Entities (27, 28); Relationships (44, 40)].",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '4'},
#   {'id': '9',
#    'title': 'After-Sales Service Department and Related Installations',
#    'occurrence weight': 0.8571428571428571,
#    'content': "# After-Sales Service Department and Related Installations\n\nThe community is centered around the After-Sales Service Department, which plays a crucial role in providing support and consultation for various installations and structural modifications. Key entities include the After-Sales Service Department, installation contractors, and specific components like exhaust and intake pipes. The department's responsibilities span from ensuring the safety and efficiency of gas water heaters to advising on floor reinforcement for heavy installations.\n\n## Central Role of the After-Sales Service Department\n\nThe After-Sales Service Department is pivotal in this community, providing a wide range of support and consultation services. It ensures the structural integrity and safety of installations, such as floor reinforcement when heavy objects are placed, and addresses issues related to gas and oil water heaters. This department's comprehensive support is crucial for maintaining customer satisfaction and product reliability [Data: Entities (59); Relationships (83, 89, 90, 84, 85, +more)].\n\n## Importance of Floor Reinforcement Guidance\n\nThe After-Sales Service Department provides essential guidance on floor reinforcement, particularly when the weight limit of 180kg per square meter is exceeded. This is especially relevant for installations like waterbeds, which can weigh between 100-500kg. Proper reinforcement is necessary to prevent structural damage and ensure safety [Data: Entities (61, 63); Relationships (81, 82)].\n\n## Handling of Gas Water Heater Issues\n\nThe department is responsible for addressing issues related to gas water heaters, including abnormal combustion and malfunctions. This involves collaboration with installation contractors to ensure that exhaust and intake pipes are correctly connected and functioning safely. The department's role is critical in preventing potential hazards associated with these appliances [Data: Entities (251); Relationships (89, 90, 88, 253)].\n\n## Consultation for External Wall and Structure Modifications\n\nThe After-Sales Service Department offers consultation services for modifications to external walls and other structures. This includes addressing specific installation requirements that may not be initially met, ensuring that all structural changes comply with safety standards. Such consultations are vital for maintaining the integrity of buildings and preventing future issues [Data: Relationships (84)].\n\n## Comprehensive Customer Support and Product Registration\n\nBeyond technical support, the After-Sales Service Department manages product registration and customer inquiries, particularly concerning water purifier cartridge replacements. This comprehensive support system is designed to enhance customer satisfaction and ensure the reliability of products, reflecting the department's commitment to quality service [Data: Entities (59)].",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '9'},
#   {'id': '1',
#    'title': 'Hokkaido Water Infrastructure and Freezing Challenges',
#    'occurrence weight': 0.42857142857142855,
#    'content': "# Hokkaido Water Infrastructure and Freezing Challenges\n\nThe community focuses on the unique challenges faced by Hokkaido, a region in Japan, due to its colder climate. Key entities include water pipes, water meters, and water heaters, all of which are susceptible to freezing. The relationships between these entities highlight the need for specific measures to prevent damage and ensure functionality during cold weather.\n\n## Hokkaido's unique climate requirements\n\nHokkaido, a region in Japan, has specific requirements due to its colder climate. This necessitates different specifications for systems such as the 24-hour ventilation system to ensure they function effectively in the region's unique conditions [Data: Entities (43); Relationships (62)].\n\n## Freezing risks to water pipes\n\nWater pipes in Hokkaido are at risk of freezing, which can lead to blockages or even bursting. This is a significant concern as it can cause extensive damage and disrupt water supply. Specific instructions for draining these pipes are necessary to mitigate these risks [Data: Entities (178); Relationships (63, 197)].\n\n## Impact of freezing on water meters\n\nWater meters in Hokkaido are also vulnerable to freezing, which can lead to malfunctions. This poses a risk to accurate water usage measurement and billing, highlighting the need for protective measures against freezing [Data: Entities (177); Relationships (198)].\n\n## Necessity of draining water heaters\n\nIn addition to water pipes, water heaters must also be drained to prevent damage from freezing. This is crucial to maintain the functionality of water heating systems during the cold months in Hokkaido [Data: Entities (243); Relationships (199)].\n\n## Comprehensive approach to prevent freezing\n\nA comprehensive approach is required to address the freezing challenges in Hokkaido. This includes specific instructions for draining water pipes and heaters, as well as ensuring that all systems are designed to withstand the region's cold climate [Data: Entities (43, 178, 243); Relationships (63, 199)].",
#    'rank': 7.5,
#    'index_name': 'test-01',
#    'index_id': '1'},
#   {'id': '11',
#    'title': 'Installation Contractors and Gas Water Heater System',
#    'occurrence weight': 0.2857142857142857,
#    'content': "# Installation Contractors and Gas Water Heater System\n\nThe community is centered around installation contractors responsible for setting up and maintaining gas water heaters, with significant interactions involving the after-sales service department, gas meters, and related components such as piping and the main unit. These entities work together to ensure the efficient operation and maintenance of gas water heating systems.\n\n## Role of Installation Contractors\n\nInstallation contractors, referred to as '設置業者', play a pivotal role in the community by being responsible for setting up and maintaining both gas and oil water heaters. They ensure that these systems are properly installed and functioning efficiently, providing assistance in case of malfunctions [Data: Entities (249); Relationships (254, 251, 252, 253)]. Their involvement is crucial for the safety and reliability of the water heating systems, as they are the primary point of contact for any issues related to the installation and maintenance of these systems.\n\n## Interaction with After-Sales Service Department\n\nThe after-sales service department is a key entity that interacts closely with installation contractors. It is contacted for issues related to gas water heaters, including the main unit and piping system [Data: Relationships (89, 90, 86, 87)]. This department plays a vital role in addressing customer concerns and ensuring that any abnormalities in the system are promptly reported and resolved. The collaboration between the after-sales service department and installation contractors is essential for maintaining the operational integrity of the water heating systems.\n\n## Importance of the Gas Meter\n\nThe gas meter, identified as 'ガスメーター', is an important component in the community, as it monitors gas usage and provides indicators for necessary actions, such as resetting in case of malfunction [Data: Entities (332); Relationships (314)]. It is used to manage the gas supply to the gas water heater, ensuring that the system operates within safe and efficient parameters. The gas meter's role is critical in preventing potential hazards associated with gas usage and maintaining the overall safety of the heating system.\n\n## Maintenance of Piping System\n\nThe piping system, referred to as '配管', is another crucial element in the community. It is connected to the oil water heater and should be checked for leaks to prevent any potential safety hazards [Data: Entities (250); Relationships (252, 87)]. Both the installation contractors and the after-sales service department are responsible for addressing any abnormalities in the piping system, highlighting the importance of regular maintenance and inspection to ensure the system's safety and efficiency.\n\n## Significance of the Main Unit\n\nThe main unit, identified as '本体', is a central component of the gas water heater system. It should be reported to both the installation contractor and the after-sales service department if any abnormalities are found [Data: Entities (252); Relationships (251, 86)]. The main unit's proper functioning is essential for the overall performance of the water heating system, and any issues with it can significantly impact the system's efficiency and safety. Regular monitoring and maintenance of the main unit are therefore critical.",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '11'},
#   {'id': '8',
#    'title': '第1種換気システム and Associated Filters',
#    'occurrence weight': 0.2857142857142857,
#    'content': "# 第1種換気システム and Associated Filters\n\nThe community is centered around the 第1種換気システム, also known as the Air Factory, which is a ventilation system used in residential areas such as ハイム and デシオGT. This system includes various components like the 除塵フィルター, NO2フィルター, and 排気グリル用フィルター, each playing a crucial role in its maintenance and operation.\n\n## Central role of 第1種換気システム\n\nThe 第1種換気システム, also referred to as the Air Factory, is the central entity in this community. It is a comprehensive ventilation system used in residential areas such as ハイム and デシオGT, highlighting its importance in ensuring air quality and comfort in these environments. The system's maintenance involves several components, each with specific roles and maintenance schedules, underscoring its complexity and the need for regular upkeep [Data: Entities (308); Relationships (42, 45, 75)].\n\n## Importance of 除塵フィルター\n\nThe 除塵フィルター is a critical component of the 第1種換気システム, designed specifically to remove dust and maintain air quality. It requires replacement every five years, indicating its significant role in the system's maintenance routine. The filter's specific dimensions and dust removal capabilities are tailored to ensure optimal performance, making it an indispensable part of the ventilation system [Data: Entities (53); Relationships (80, 71, 77)].\n\n## Maintenance of NO2フィルター\n\nThe NO2フィルター is another essential component of the 第1種換気システム, involved in its maintenance. This filter plays a crucial role in managing air quality by filtering out nitrogen dioxide, a common pollutant. Its inclusion in the system's maintenance highlights the comprehensive approach taken to ensure the ventilation system's effectiveness in residential areas [Data: Relationships (79)].\n\n## Role of 排気グリル用フィルター\n\nThe 排気グリル用フィルター is part of the 第1種換気システム's maintenance, contributing to the system's overall functionality. This filter is specifically designed for use in exhaust grills, playing a vital role in the ventilation process by ensuring that air expelled from the system is free of contaminants. Its maintenance is crucial for the system's efficiency and longevity [Data: Relationships (295)].\n\n## 床タラリ event in maintenance\n\nThe 床タラリ event refers to the scheduled replacement of a specific filter every ten years as part of the 第1種換気システム's maintenance. This long-term maintenance schedule indicates the durability and reliability of the components used in the system, as well as the importance of adhering to maintenance timelines to ensure continued performance and air quality [Data: Entities (309); Relationships (296)].",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '8'},
#   {'id': '7',
#    'title': 'エアーファクトリー and Air Filtration Systems',
#    'occurrence weight': 0.2857142857142857,
#    'content': "# エアーファクトリー and Air Filtration Systems\n\nThe community is centered around エアーファクトリー, a company involved in air filtration systems, and its associated entities such as 空気工房 and various filters like NO2フィルター and プレフィルター. These entities are interconnected through maintenance and operational instructions, highlighting their collaborative role in ensuring efficient air filtration.\n\n## エアーファクトリー as a central entity\n\nエアーファクトリー is the central entity in this community, known for its involvement in air filtration systems under the alias 第1種換気システム. It provides maintenance instructions for various filters, ensuring their efficient operation and longevity. This central role underscores its importance in the community's structure and operations [Data: Entities (50); Relationships (75, 70, 71, 72, 74, 73)].\n\n## Role of 空気工房 in maintenance\n\n空気工房 is closely associated with エアーファクトリー, playing a significant role in the maintenance of air filtration systems. It is involved in the upkeep of filters such as NO2フィルター and プレフィルター, which are crucial for maintaining optimal air quality. This relationship highlights the collaborative efforts between these entities to ensure effective air filtration [Data: Entities (51); Relationships (69, 76, 77, 78)].\n\n## Significance of NO2フィルター\n\nNO2フィルター is a critical component of the air filtration system, requiring replacement every five years to maintain optimal performance. Its integration into the system underscores its importance in ensuring air quality, and its maintenance is a shared responsibility between エアーファクトリー and 空気工房 [Data: Entities (52); Relationships (79, 70, 76)].\n\n## Maintenance of プレフィルター\n\nThe プレフィルター is another essential filter within the air filtration system, necessitating cleaning every three months. This regular maintenance is vital for the system's efficiency and is supported by both エアーファクトリー and 空気工房, reflecting their joint commitment to air quality [Data: Entities (54); Relationships (72, 78)].\n\n## Installation guidance for filter boxes\n\nエアーファクトリー provides detailed instructions for installing filter boxes in various locations, such as D and M2. This guidance is crucial for ensuring the proper setup and functionality of the air filtration systems, further emphasizing the company's comprehensive approach to air quality management [Data: Relationships (74, 73)].",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '7'},
#   {'id': '6',
#    'title': '換気ガラリ Ventilation System',
#    'occurrence weight': 0.2857142857142857,
#    'content': "# 換気ガラリ Ventilation System\n\nThe community is centered around the 換気ガラリ, a ventilation system component that includes several parts such as the フィルター, 換気ガラリカバー, 室内カバー, and 調整ツマミ. These components are interconnected, with the フィルター playing a crucial role in air purification and maintenance being essential for optimal performance.\n\n## Role of フィルター in air purification\n\nThe フィルター is a critical component of the 換気ガラリ, responsible for filtering air to ensure it is clean and free from impurities. Regular maintenance, including cleaning and replacement, is essential to maintain its effectiveness and ensure optimal air quality. This highlights the importance of the フィルター in the overall functionality of the ventilation system [Data: Entities (288); Relationships (283, 287)].\n\n## 換気ガラリ as the central component\n\nThe 換気ガラリ serves as the central component of the ventilation system, integrating various parts such as the フィルター, 換気ガラリカバー, 室内カバー, and 調整ツマミ. Each of these components plays a specific role in the system's operation, with the 換気ガラリ acting as the hub that connects them all. This centrality underscores its importance in ensuring the system's efficiency and effectiveness [Data: Entities (287); Relationships (283, 284, 285, 286)].\n\n## Importance of 換気ガラリカバー\n\nThe 換気ガラリカバー is a removable cover for the 換気ガラリ, facilitating maintenance activities. Its design allows for easy access to the internal components of the 換気ガラリ, making it easier to perform necessary cleaning and replacement tasks. This feature is crucial for maintaining the system's performance and prolonging its lifespan [Data: Entities (289); Relationships (284)].\n\n## Function of 調整ツマミ\n\nThe 調整ツマミ is a part of the ventilation system used to adjust the settings of the 換気ガラリ. This component allows users to control the system's operation, ensuring that it meets specific ventilation needs. The ability to adjust settings is vital for optimizing the system's performance and adapting to different environmental conditions [Data: Entities (290); Relationships (286)].\n\n## Maintenance of 室内カバー\n\nThe 室内カバー is part of the 換気ガラリ system and can be removed for maintenance. This feature is important for ensuring that the internal components of the system are accessible for cleaning and inspection. Regular maintenance of the 室内カバー is necessary to prevent dust and debris accumulation, which can affect the system's efficiency [Data: Entities (291); Relationships (285)].",
#    'rank': 4.5,
#    'index_name': 'test-01',
#    'index_id': '6'},
#   {'id': '5',
#    'title': 'Balcony and Related Installations',
#    'occurrence weight': 0.2857142857142857,
#    'content': "# Balcony and Related Installations\n\nThe community centers around the 'バルコニー' (Balcony) entity, which is integral to residential structures and involves various maintenance and installation activities. Key relationships include the installation of storage sheds or greenhouses, the role of the After-Sales Service Department, and the importance of cleaning during specific seasons like the rainy and typhoon seasons.\n\n## Balcony as a central entity\n\nThe 'バルコニー' (Balcony) is a central entity in this community, serving as a critical component of residential structures. It is prone to accumulating dust and debris, necessitating regular cleaning, especially during the rainy and typhoon seasons. The balcony's maintenance is crucial to prevent potential hazards, such as water damage or structural issues, which could arise from neglect or improper modifications [Data: Entities (18); Relationships (19, 22, 20, 21)].\n\n## Importance of cleaning the balcony\n\nCleaning the balcony is essential to remove accumulated dust and debris, which is particularly important during the rainy season ('梅雨') and before the typhoon season ('台風シーズン'). Regular cleaning helps maintain the structural integrity of the balcony and prevents blockages in drainage systems, such as the '樋落とし口' (drainage outlet), which is part of the balcony's design [Data: Entities (18, 19, 20, 21); Relationships (22, 24)].\n\n## Role of the After-Sales Service Department\n\nThe After-Sales Service Department plays a significant role in the installation of storage sheds or greenhouses on balconies. Their involvement is crucial to ensure that installations are done correctly, avoiding damage to external walls and minimizing potential hazards during strong winds. This highlights the importance of professional oversight in modifications involving balconies [Data: Entities (94); Relationships (85)].\n\n## Installation of storage sheds or greenhouses\n\nThe installation of storage sheds or greenhouses on balconies requires careful consideration to avoid structural damage and ensure safety. This process often involves consulting with the After-Sales Service Department to ensure proper placement and adherence to safety standards. Such installations can impact the overall safety and functionality of the balcony if not executed properly [Data: Entities (94); Relationships (23, 85)].\n\n## Mesh-type flooring by ハイム（ツーユー）\n\nThe housing manufacturer 'ハイム（ツーユー）' uses mesh-type flooring materials for balconies, which can influence maintenance practices and the overall durability of the balcony. This choice of material may affect how debris accumulates and how water drains, thus impacting the cleaning and maintenance requirements of the balcony [Data: Entities (17); Relationships (18)].",
#    'rank': 4.5,
#    'index_name': 'test-01',
#    'index_id': '5'},
#   {'id': '0',
#    'title': '24-Hour Ventilation System and Associated Components',
#    'occurrence weight': 0.14285714285714285,
#    'content': "# 24-Hour Ventilation System and Associated Components\n\nThe community is centered around the 24-hour ventilation system, which integrates various components such as the hall ventilation fan, toilet ventilation fan, bath core ventilation fan, range hood, and room ventilation grille. These components are designed to provide continuous ventilation and improve air quality in residential settings, with specific adaptations for different regions like 北海道.\n\n## Central Role of the 24-Hour Ventilation System\n\nThe 24-hour ventilation system is the central entity in this community, designed to ensure continuous air changes throughout the year. It plays a crucial role in maintaining indoor air quality by integrating various components that address different ventilation needs in residential settings. This system is particularly significant in regions with specific climate conditions, such as 北海道, where it has tailored specifications to meet local requirements [Data: Entities (44); Relationships (58, 62)].\n\n## Integration of Hall Ventilation Fan\n\nThe hall ventilation fan is an integral part of the 24-hour ventilation system, contributing to the overall air exchange process. Its inclusion in the system highlights the importance of addressing ventilation in common areas of residential buildings, ensuring that air quality is maintained throughout the entire living space [Data: Entities (49); Relationships (64)].\n\n## Functionality of the Toilet Ventilation Fan\n\nThe toilet ventilation fan is designed for continuous weak airflow, specifically to expel moisture and odors while minimizing the impact of cold air. This component is essential for maintaining hygiene and comfort in bathroom areas, and its integration into the 24-hour ventilation system underscores its role in comprehensive residential ventilation solutions [Data: Entities (45); Relationships (65)].\n\n## Bath Core Ventilation Fan's Dual Functionality\n\nThe bath core ventilation fan is notable for its dual functionality, providing continuous moisture exchange and integrating bathroom drying functions. This component is crucial for preventing mold and mildew in humid environments, making it a vital part of the 24-hour ventilation system's efforts to enhance indoor air quality [Data: Entities (46); Relationships (66)].\n\n## Role of the Range Hood in Kitchen Ventilation\n\nThe range hood is a key component of the 24-hour ventilation system, specifically designed to expel cooking fumes and steam from kitchen areas. Its inclusion in the system highlights the importance of addressing air quality in areas prone to high levels of pollutants, ensuring a healthier living environment [Data: Entities (47); Relationships (67)].\n\n## Room Ventilation Grille's Contribution to Air Quality\n\nThe room ventilation grille, equipped with a filter to reduce dust and pollen intrusion, is an important part of the 24-hour ventilation system. This component plays a significant role in maintaining air quality in living spaces, particularly for individuals with allergies or respiratory issues, by minimizing the entry of outdoor pollutants [Data: Entities (48); Relationships (68)].",
#    'rank': 6.5,
#    'index_name': 'test-01',
#    'index_id': '0'},
#   {'id': '10',
#    'title': 'External Wall Construction and After-Sales Service',
#    'occurrence weight': 0.14285714285714285,
#    'content': "# External Wall Construction and After-Sales Service\n\nThe community is centered around external wall construction, involving entities such as the After-Sales Service Department and the external wall itself. The After-Sales Service Department provides consultation services for external wall construction, which involves modifications to the external wall.\n\n## Role of the After-Sales Service Department\n\nThe After-Sales Service Department plays a crucial role in this community by providing consultation services for external wall construction. This department's involvement suggests a structured approach to managing the complexities associated with external wall modifications, which may include drilling holes or attaching items that require reinforcement or special tools. The presence of a dedicated service department indicates the importance of ensuring quality and safety in construction projects [Data: Relationships (84)].\n\n## Complexities of External Wall Construction\n\nExternal wall construction is a complex process that involves making modifications to the external wall. These modifications can include drilling holes or attaching items, which may necessitate reinforcement or the use of special tools. The technical nature of these tasks underscores the need for expert consultation and careful planning to ensure structural integrity and compliance with safety standards [Data: Entities (92); Relationships (115)].\n\n## Interconnection between External Wall and Construction\n\nThe relationship between external wall construction and the external wall itself is fundamental to understanding this community. External wall construction directly involves modifications to the external wall, highlighting the interdependent nature of these entities. This interconnection emphasizes the need for precise execution and adherence to construction guidelines to maintain the wall's functionality and appearance [Data: Relationships (115)].",
#    'rank': 4.0,
#    'index_name': 'test-01',
#    'index_id': '10'}],
#  'entities': [],
#  'relationships': [],
#  'claims': [],
#  'sources': []}

# %% [markdown]
# ### Local Query
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time


def local_search(
    index_name: str | list[str], query: str, community_level: int
) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    # optional parameter: community level to query the graph at (default for local query = 2)
    request = {
        "index_name": index_name,
        "query": query,
        "community_level": community_level,
    }
    return requests.post(url, json=request, headers=headers)


# perform a local query
local_response = local_search(
    index_name=index_name,
    query="このデータに見られる主なトピックをまとめて",
    community_level=2,
)
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# 以下に、提供されたデータに基づく主なトピックをまとめます。
#
# ### 1. ハイムとデシオGTの住宅地域
#
# ハイムとデシオGTは、特定の建設およびメンテナンス要件を持つ住宅地域です。これらの地域では、石膏ボードを使用した壁や天井の建設が行われており、木製スタッドの位置や釘やネジの固定に特別な注意が必要です。この建設方法は、構造の耐久性と安全性を維持するために特定のガイドラインに従うことが求められます [Data: Entities (27, 28); Relationships (39, 43, 44, 40)]。
#
# ### 2. 換気システムと空調設備
#
# これらの住宅地域では、第1種換気システムが使用されており、住民の快適さと空気の質を維持するために重要です。これらのシステムは、生活環境に不可欠であり、定期的なメンテナンスが必要です [Data: Relationships (45, 42)]。また、エアコンの室内機の設置には、特定の材料と方法が必要であり、デコスケやツーユーなどの材料が使用されます [Data: Entities (64); Relationships (83, 61, 92, 93, 94)]。
#
# ### 3. ツーユーの役割
#
# ツーユーは、住宅地域の建設において重要な役割を果たしており、壁の建設やエアコンの設置に必要な材料を提供しています。ツーユーは、石膏ボードと組み合わせて使用され、構造の完全性と機能性を確保するために重要です [Data: Entities (42); Relationships (58, 59, 60, 61)]。
#
# ### 4. メンテナンスと安全ガイドライン
#
# ハイムとデシオGTの住宅地域には、快適で安全な生活環境を確保するための詳細なメンテナンスと安全ガイドラインがあります。これらのガイドラインは、天井や壁の荷重制限や換気システムのメンテナンスなどの側面をカバーしています。これらのガイドラインに従うことは、住宅地域の構造的完全性と安全性を維持するために重要です [Data: Entities (27, 28); Relationships (44, 40)]。
#
# これらのトピックは、住宅地域の建設、設備、メンテナンスに関する重要な要素を強調しており、住民の生活の質を向上させるための取り組みを示しています。
# CPU times: user 32.5 ms, sys: 570 μs, total: 33.1 ms
# Wall time: 33.7 s
# {'reports': [{'id': '4',
#    'title': 'ハイム and デシオGT Residential Areas',
#    'content': "# ハイム and デシオGT Residential Areas\n\nThe community is centered around the residential areas of ハイム and デシオGT, which are characterized by specific construction and maintenance requirements. These areas utilize gypsum board construction and have detailed guidelines for ventilation systems and air conditioner installations, involving entities like ツーユー and エアコン室内機.\n\n## Unique construction features of ハイム and デシオGT\n\nBoth ハイム and デシオGT are residential areas with unique construction features that involve the use of gypsum board for walls and ceilings. This construction method requires specific attention to the positioning of wood studs and the fixing of nails or screws to ensure structural integrity and safety. The use of gypsum board necessitates adherence to specific guidelines to maintain the durability and safety of the structures [Data: Entities (27, 28); Relationships (39, 43, 44, 40)].\n\n## Ventilation systems in residential areas\n\nThe residential areas of ハイム and デシオGT are equipped with specific ventilation systems to ensure proper air circulation and comfort. The 第1種換気システム is used in both areas, highlighting the importance of maintaining air quality and comfort for residents. These systems are integral to the living environment and require regular maintenance as outlined in the applicable guides [Data: Relationships (45, 42)].\n\n## Role of ツーユー in construction\n\nツーユー plays a significant role in the construction of residential areas by providing materials for wall construction and air conditioner installations. It is characterized by a wood stud position width of 455mm and is used in conjunction with gypsum board, which requires specific fixing methods. This highlights the versatility and importance of ツーユー in ensuring the structural integrity and functionality of residential constructions [Data: Entities (42); Relationships (58, 59, 60, 61)].\n\n## Air conditioner installation requirements\n\nThe installation of air conditioners in these residential areas involves specific materials and methods. The indoor unit, エアコン室内機, requires particular installation techniques as illustrated in diagrams A and B. Materials like デコスケ and ツーユー are used to ensure proper installation and functionality. The after-sales service department provides support for these installations, emphasizing the technical complexity and importance of following precise guidelines [Data: Entities (64); Relationships (83, 61, 92, 93, 94)].\n\n## Maintenance and safety guidelines\n\nThe residential areas of ハイム and デシオGT have detailed maintenance and safety guidelines to ensure a comfortable and safe living environment. These guidelines cover aspects such as load limits for ceilings and walls, and the maintenance of ventilation systems. Adhering to these guidelines is crucial for maintaining the structural integrity and safety of the residential areas, highlighting the community's focus on quality and safety [Data: Entities (27, 28); Relationships (44, 40)].",
#    'index_name': 'test-01',
#    'index_id': '4'},
#   {'id': '4',
#    'title': 'ハイム and デシオGT Residential Areas',
#    'content': "# ハイム and デシオGT Residential Areas\n\nThe community is centered around the residential areas of ハイム and デシオGT, which are characterized by specific construction and maintenance requirements. These areas utilize gypsum board construction and have detailed guidelines for ventilation systems and air conditioner installations, involving entities like ツーユー and エアコン室内機.\n\n## Unique construction features of ハイム and デシオGT\n\nBoth ハイム and デシオGT are residential areas with unique construction features that involve the use of gypsum board for walls and ceilings. This construction method requires specific attention to the positioning of wood studs and the fixing of nails or screws to ensure structural integrity and safety. The use of gypsum board necessitates adherence to specific guidelines to maintain the durability and safety of the structures [Data: Entities (27, 28); Relationships (39, 43, 44, 40)].\n\n## Ventilation systems in residential areas\n\nThe residential areas of ハイム and デシオGT are equipped with specific ventilation systems to ensure proper air circulation and comfort. The 第1種換気システム is used in both areas, highlighting the importance of maintaining air quality and comfort for residents. These systems are integral to the living environment and require regular maintenance as outlined in the applicable guides [Data: Relationships (45, 42)].\n\n## Role of ツーユー in construction\n\nツーユー plays a significant role in the construction of residential areas by providing materials for wall construction and air conditioner installations. It is characterized by a wood stud position width of 455mm and is used in conjunction with gypsum board, which requires specific fixing methods. This highlights the versatility and importance of ツーユー in ensuring the structural integrity and functionality of residential constructions [Data: Entities (42); Relationships (58, 59, 60, 61)].\n\n## Air conditioner installation requirements\n\nThe installation of air conditioners in these residential areas involves specific materials and methods. The indoor unit, エアコン室内機, requires particular installation techniques as illustrated in diagrams A and B. Materials like デコスケ and ツーユー are used to ensure proper installation and functionality. The after-sales service department provides support for these installations, emphasizing the technical complexity and importance of following precise guidelines [Data: Entities (64); Relationships (83, 61, 92, 93, 94)].\n\n## Maintenance and safety guidelines\n\nThe residential areas of ハイム and デシオGT have detailed maintenance and safety guidelines to ensure a comfortable and safe living environment. These guidelines cover aspects such as load limits for ceilings and walls, and the maintenance of ventilation systems. Adhering to these guidelines is crucial for maintaining the structural integrity and safety of the residential areas, highlighting the community's focus on quality and safety [Data: Entities (27, 28); Relationships (44, 40)].",
#    'index_name': 'test-01',
#    'index_id': '4'}],
#  'entities': [{'id': '275',
#    'entity': 'トッププレート',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 275},
#   {'id': '67',
#    'entity': '図A',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 67},
#   {'id': '252',
#    'entity': '本体',
#    'description': '',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 252},
#   {'id': '6',
#    'entity': 'JAPAN',
#    'description': 'The document is written in Japanese and is relevant to Japan, focusing on issues pertinent to Japanese homes. It discusses various domestic concerns such as the use of tatami mats, measures against mold and salt damage—common problems in Japan due to its humid climate—and rodent control measures. The consistent use of the Japanese language throughout the text underscores its connection to Japan and its geographical and cultural context.',
#    'number of relationships': '4',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 6},
#   {'id': '322',
#    'entity': 'SUPPORT MATERIAL',
#    'description': '',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 322},
#   {'id': '292',
#    'entity': 'アレルギー 33(3), 455',
#    'description': 'A publication by the Japanese Allergy Society that discusses the distribution density of mites in homes and their impact on allergies',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 292},
#   {'id': '31',
#    'entity': 'グラフテ',
#    'description': 'グラフテ is another place where filters for 快適エアリー can be purchased',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 31},
#   {'id': '118',
#    'entity': '日本',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 118},
#   {'id': '357',
#    'entity': 'VTOHスタンド',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 357},
#   {'id': '21',
#    'entity': '台風シーズン',
#    'description': '台風シーズンは日本で台風が多く発生する時期です',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 21},
#   {'id': '306',
#    'entity': '専門業者',
#    'description': '専門業者は燃料電池ユニットの定期点検を行うために必要な組織です',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 306},
#   {'id': '184',
#    'entity': '次亜塩素酸ナトリウム',
#    'description': '',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 184},
#   {'id': '88',
#    'entity': 'ローラー式粘着テープ',
#    'description': 'A roller-type adhesive tape used for easily picking up dust from carpets and broken glass pieces)<|COMPLETE|>I apologize for the oversight. Let\'s identify additional entities and relationships from the text:("entity"',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 88},
#   {'id': '366',
#    'entity': 'かなづち',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 366},
#   {'id': '296',
#    'entity': '家屋内のダニの分布密度例',
#    'description': 'An example illustrating the distribution density of mites within a house, highlighting areas like carpets and closets',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 296},
#   {'id': '375',
#    'entity': '維持管理業者',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 375},
#   {'id': '141',
#    'entity': 'パワーコンディショナー本体',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 141},
#   {'id': '286',
#    'entity': '電源',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 286},
#   {'id': '105',
#    'entity': '玄関柱・格子',
#    'description': 'The structural elements around the entrance, made of aluminum, which require regular maintenance to prevent corrosion)<|COMPLETE|>I apologize for the oversight. Let\'s identify additional entities and relationships from the text:("entity"',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 105},
#   {'id': '165',
#    'entity': 'アフターサービス',
#    'description': '',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 165}],
#  'relationships': [{'id': '178',
#    'source': 'ニチコン',
#    'target': 'VTOHスタンド',
#    'description': 'ニチコン manufactures the VtoHスタンド for vehicle-to-home power transfer',
#    'weight': '8.0',
#    'rank': '13',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 178},
#   {'id': '86',
#    'source': 'アフターサービス部門',
#    'target': '本体',
#    'description': 'The main unit should be reported to the after-sales service department if any abnormalities are found',
#    'weight': '7.0',
#    'rank': '12',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 86},
#   {'id': '6',
#    'source': 'JAPAN',
#    'target': 'ELECTRICAL OUTLET',
#    'description': 'The guidelines for electrical outlet use are written in Japanese, suggesting relevance to Japan',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 6},
#   {'id': '111',
#    'source': '掃除機',
#    'target': 'ローラー式粘着テープ',
#    'description': 'The vacuum cleaner is complemented by roller-type adhesive tape for picking up debris',
#    'weight': '5.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 111},
#   {'id': '186',
#    'source': '蓄電池システム',
#    'target': 'アフターサービス',
#    'description': 'The after-sales service should be contacted for repairs, relocation, or reinstallation of the battery storage system',
#    'weight': '7.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 186},
#   {'id': '261',
#    'source': 'IHクッキングヒーター',
#    'target': 'トッププレート',
#    'description': 'The top plate is a component of the IHクッキングヒーター that requires careful cleaning',
#    'weight': '6.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 261},
#   {'id': '8',
#    'source': 'JAPAN',
#    'target': 'TOILET MAINTENANCE',
#    'description': 'The document is written in Japanese, suggesting it is intended for a Japanese audience regarding toilet maintenance',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 8},
#   {'id': '21',
#    'source': 'バルコニー',
#    'target': '台風シーズン',
#    'description': '台風シーズン前にはバルコニーの清掃が推奨されます',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 21},
#   {'id': '50',
#    'source': '快適エアリー',
#    'target': 'グラフテ',
#    'description': 'グラフテ sells filters for the 快適エアリー system',
#    'weight': '5.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 50},
#   {'id': '251',
#    'source': '設置業者',
#    'target': '本体',
#    'description': 'The main unit should be reported to the installation contractor if any abnormalities are found',
#    'weight': '7.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 251},
#   {'id': '7',
#    'source': 'JAPAN',
#    'target': 'TATAMI MATS',
#    'description': 'Tatami mats are a traditional Japanese flooring, indicating the cultural context of the document',
#    'weight': '1.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 7},
#   {'id': '9',
#    'source': 'JAPAN',
#    'target': 'POISON BAIT',
#    'description': 'The text advises caution with poison bait in a Japanese domestic context',
#    'weight': '1.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 9},
#   {'id': '93',
#    'source': 'エアコン室内機',
#    'target': '図A',
#    'description': 'Diagram A provides specific installation instructions for the air conditioner indoor unit',
#    'weight': '6.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 93},
#   {'id': '188',
#    'source': '蓄電パワーコンディショナ',
#    'target': 'アフターサービス',
#    'description': 'The after-sales service should be contacted if there are issues with the 蓄電パワーコンディショナ',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 188},
#   {'id': '189',
#    'source': '蓄電ユニット',
#    'target': 'アフターサービス',
#    'description': 'The after-sales service should be contacted if the 蓄電ユニット falls during an earthquake',
#    'weight': '7.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 189},
#   {'id': '293',
#    'source': 'エネファーム',
#    'target': '専門業者',
#    'description': '専門業者はエネファームの燃料電池ユニットの定期点検を行います',
#    'weight': '8.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 293},
#   {'id': '304',
#    'source': 'RETAINING DEVICE B TYPE',
#    'target': 'SUPPORT MATERIAL',
#    'description': 'Retaining Device B Type is inserted and locked into the slit of the support material',
#    'weight': '6.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 304},
#   {'id': '122',
#    'source': '玄関柱・格子',
#    'target': 'アルミ',
#    'description': 'Aluminum is the material used for the entrance pillars and lattice, which requires maintenance to prevent corrosion',
#    'weight': '8.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 122},
#   {'id': '133',
#    'source': 'ほっといて',
#    'target': '日本',
#    'description': "The product 'ほっといて' is marketed and used in Japan",
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 133},
#   {'id': '276',
#    'source': '感電',
#    'target': '電源',
#    'description': 'Turning off the power source is necessary to prevent electric shock',
#    'weight': '8.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 276},
#   {'id': '291',
#    'source': '快適情報',
#    'target': '家屋内のダニの分布密度例',
#    'description': 'Understanding the distribution density of mites helps in creating strategies for a comfortable living environment',
#    'weight': '6.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 291},
#   {'id': '303',
#    'source': 'RETAINING DEVICE A TYPE',
#    'target': 'SUPPORT MATERIAL',
#    'description': 'Retaining Device A Type is inserted and locked into the slit of the support material',
#    'weight': '6.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 303},
#   {'id': '339',
#    'source': '浄化槽',
#    'target': '維持管理業者',
#    'description': 'Users of 浄化槽 must contract with 維持管理業者 for maintenance',
#    'weight': '7.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 339},
#   {'id': '121',
#    'source': '玄関ステップ',
#    'target': '玄関柱・格子',
#    'description': 'The cleaning of the entrance steps involves ensuring that the entrance pillars and lattice are not damaged by cleaning agents',
#    'weight': '7.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 121},
#   {'id': '200',
#    'source': 'カビキラー',
#    'target': '次亜塩素酸ナトリウム',
#    'description': 'カビキラー contains 次亜塩素酸ナトリウム as an active ingredient for mold removal',
#    'weight': '7.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 200},
#   {'id': '201',
#    'source': 'カビ取りハイター',
#    'target': '次亜塩素酸ナトリウム',
#    'description': 'カビ取りハイター contains 次亜塩素酸ナトリウム as an active ingredient for mold removal',
#    'weight': '1.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 201},
#   {'id': '329',
#    'source': 'クギを打つ',
#    'target': 'かなづち',
#    'description': 'The hammering process involves using a hammer to drive nails',
#    'weight': '8.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 329},
#   {'id': '288',
#    'source': 'アレルギー 33(3), 455',
#    'target': '日本アレルギー学会',
#    'description': 'The publication is a work of the Japanese Allergy Society',
#    'weight': '9.0',
#    'rank': '2',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 288},
#   {'id': '159',
#    'source': '操作表示ユニット',
#    'target': 'パワーコンディショナー本体',
#    'description': 'The operation display unit is part of the power conditioner system',
#    'weight': '7.0',
#    'rank': '2',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test-01',
#    'index_id': 159}],
#  'claims': [],
#  'sources': [{'id': '47',
#    'text': '# Item 158\n## content\nIHクッキングヒーターの使用に関する注意事項とお手入れ方法が記載されています。\n\n### お手入れ\n- **手順1:** トッププレートはざらざらで水拭きします。\n- **手順2:** ガンコな汚れは、クリームクレンザーを少量つけ、アルミホイルを丸めてこすり取り、その後、水拭きします。\n- **手順3:** 操作パネルは、から拭きして汚れを拭き取ります。\n\n### 注意事項\n- **事故の原因:** 心臓用ペースメーカーを使用の方は、磁気が心臓用ペースメーカーの機能を狂わせる場合があるため、必ず医師に相談すること。\n- **火災の原因:** 缶詰、アルミ食器やアルミパックの食品などを置かないこと。鍋の下に布巾を置かないこと。揚げ物をする際は、約900cc以上の油を使用し、そばを離れないこと。使用後は必ずスイッチを切ること。\n- **やけどの原因:** 空焚きしないこと。鍋をおろした直後は、トッププレートが熱くなっているので、手を触れないこと。お手入れは電源スイッチを切り、本体が冷えてから行うこと。\n- **破損の原因:** トッププレートはガラス製であるため、物を落としたりしないこと。お手入れの際、ベンジン・シンナーなどの油を使わないこと。\n- **故障の原因:** 空焚きや出掛け間に火をつけないこと。鍋の底の凸凹に注意すること。器具の中に水が入ると故障の原因になるので、お掃除の際は水を使わないこと。\n\n'},
#   {'id': '11',
#    'text': '# Item 107\n## content\nこの画像は、エアコン室内機の取り付け工事に関する説明を含んでいます。エアコン室内機の取り付け位置について、図Aと図Bで異なる取り付け方法が示されています。\n\n- **図A**: 天井面からの距離や壁穴の位置が詳細に示されています。補強板タイプAは特に指定がない場合に使用されます。\n- **図B**: 補強板が壁やパネルのつなぎ目に渡って設置されている場合の取り付け方法です。\n\nまた、ツーユーとデコスケの取り付け用木材の寸法も示されています。\n\nエアコンの取り付け位置を指定している場合と指定していない場合の注意点が記載されています。指定している場合は、900×500程度の補強板が入っていることが示されています。指定していない場合は、補強や専用工具が必要になる可能性があるため、アフターサービス部門への相談が推奨されています。\n\nさらに、エアコン取り付け時の注意点として、周辺に一定の隙間を確保する必要があることが強調されています。\n\n'},
#   {'id': '44',
#    'text': '# Item 155\n## content\n### 石油給湯器\n\n#### 各部の点検\n- 本体の上や周囲に可燃物が置かれていませんか。\n- 本体および配管から油漏れ、油のたまり、にじみ、水漏れなどがありませんか。\n- 給排気筒（管、ホース）が正しく接続されていますか。\n\n本体や配管に異常があった場合は、アフターサービス部門または設置業者にご連絡ください。\n\n#### 各部のお手入れ\nお手入れの前には、必ず運転スイッチを「切」にして、電源プラグをコンセントから抜いてください。\n\n- **ホコリ（1カ月ごと）**\n  - リモコンや本体の汚れは乾いた布で拭くか、布に台所用洗剤を薄めて含ませ、軽く絞ってから洗剤を拭き取ります。特にリモコンは、トイレ用洗剤、酸性洗剤、シンナー、クレンザーなどの使用は絶対にやめてください。リモコンケースの割れの原因となることがあります。\n\n- **のぞき窓の掃除（1カ月に1回以上）**\n  - のぞき窓の汚れは乾いた布で拭くか、布に台所用洗剤を薄めて含ませ、軽く絞って拭きます。洗剤使用後は、水道水を布に含ませ、固く絞ってから洗剤を拭き取ってください。\n\n'},
#   {'id': '39',
#    'text': '# Item 83\n## content\n### 快適情報\n\n#### 詰まりを防ぐために 大便器\n\n- **汚物やトイレットペーパーの量に応じて「大」「小」を使い分けましょう**\n  - 汚物の大きさや量、比重の違いやトイレットペーパーの量によっては、1回目の洗浄で完全に流れずに残る場合があります。\n\n- **「大」の目安：**\n  - 大便約250gまたはトイレットペーパー（シングル）約10mまで流せます。\n\n- **「小」の目安：**\n  - 小便とトイレットペーパー（シングル）約3mまで流せます。\n  - これ以上の汚物やトイレットペーパー（シングル）を流すと便器が詰まる恐れがあります。\n\n- **必ずタンク内が満水になってから流しましょう**\n  - タンク内が満水になる前に流すと洗浄不良や詰まりの原因となります。\n\n- **小便でも便を使った後は必ず流しましょう**\n  - そのまま放置すると、小便の成分と水道水の成分が結びついて固まり、便器の洗浄不良や詰まりの原因となります。\n\n### 必ず守る\n\n#### 危険\n- **ガス中毒の原因になります**\n  - 酸性の洗浄剤と、塩素系の漂白剤は絶対に同時に使わないでください。有毒ガスを発生したりへん危険です。\n\n#### 警告\n- **悪臭の原因になります**\n  - トイレに使用する洗剤は、中性洗剤にしてください。特に次亜塩素酸ナトリウムなどは、浄化槽の中の微生物（バクテリア）を死滅させ、浄化機能を止めてしまい悪臭の原因になりますので使用は避けてください。\n\n#### 注意\n- **変形・破損の原因になります**\n  - 木製建物部に水がかかったら、すぐに拭き取ってください。\n\n'},
#   {'id': '58',
#    'text': '# Item 71\n## content\n### ネズミ対策\n\n家ネズミには、水分の多い台所や排水溝を好んで活動するドブネズミ、天井裏などを走りまわるクマネズミ、一番小さいハツカネズミの3種類がいます。ネズミは食べ物を食い散らし、あちこちをかじって汚すばかりでなく、イエダニやノミをばらまくこともあります。ネズミはとくに夜間の活動が活発になるのでエサとなるような生ゴミや食べ残しは、しっかりと始末してください。\n\n#### 予防策\n下水溝や排水口、マンホールなどは外部からの重要な侵入経路となります。全網で覆うなどしてネズミが入れないようにしておきましょう。\n\n### 駆除の方法\n\nネズミの駆除には特殊な粘着剤や粘着式のネズミ捕りが市販されています。どちらも、エサとなるような生ゴミや、食べ残したものを片づけてから仕掛けてください。ネズミは警戒心の強い動物なので、かからないからとあきらめずに数日間続けてみましょう。\n\n### 必ず守る\n\n#### 危険\n中毒事故の原因になります\n- 毒えさを散布している期間は、ペットは放さないようにしてください。\n- 小さなお子さまが誤って食べないようにしてください。万一、誤って飲みこんでしまった時には吐き出させ、直ちに医師の診断を受けてください。\n\n'},
#   {'id': '13',
#    'text': '# Item 75\n## content\nこのページは、スイッチとコンセントの使用に関する注意事項を説明しています。\n\n### コンセント\n- コンセントは1か所で1,500W以下の電気製品を使用するように注意。\n- 使用する電気製品のワット数を確認してからコンセントに差し込む。\n\n### 非常時兼用コンセントの使い方（蓄電池システム採用時）\n- 停電時に使用できるコンセントで、事前に計画した電気製品を接続して使用。\n- 空の非常時兼用コンセントは停電時以外は使用しない。\n- 消費電力の大きい電気製品を接続するとブレーカーが遮断されることがある。\n- 停電時は消費電力の範囲内で使用。\n\n### 危険\n- 発火の恐れ：タコ足配線や市販のコードを使用すると電気の容量を超える恐れがある。\n- 感電の原因：濡れた手でプラグを抜き差ししない。\n\n### 注意\n- ショートの原因：プラグを抜く時は本体を持って抜く。コードを引っ張ると中の線がショートする恐れがある。\n\n'},
#   {'id': '36',
#    'text': '# Item 109\n## content\nこの文書は、ダニ対策について説明しています。ダニは種類によって異なり、畳を食べる毛皮コナダニやフケを好むチリダニなどが存在し、アレルギーの原因になることがあります。ダニの発生は新築直後に限られていましたが、現在は住宅の気密性が向上したため、ダニの卵が越冬し毎年発生しやすくなっています。\n\n**ダニの発生と繁殖条件**\n- ダニは1年中あらゆる場所で繁殖します。\n- ダニの種類は数多く、私たちの周りには特に40種類以上のダニが生息しています。\n- 季節では6月から10月に最も多く発生します。\n- ダニが最も繁殖しやすい条件は以下の通りです：\n  1. 温度25～28℃\n  2. 湿度70～80％\n  3. エサがあり卵を産める場所（畳やカーペット敷きの部屋）\n\n**ダニの駆除方法**\n- 繁殖してから駆除するよりも日ごろから通気に心がけ、こまめなお掃除で繁殖を抑えることが大切です。\n- ダニが発生したら、エアコンの除湿運転を1日2～3回行い、部屋を乾燥させた状態に保ちます。\n- 畳やカーペットに生息するチリダニは駆除剤では駆除できませんが、50℃以上で過熱すると6時間で95％、12時間でほぼ死滅します。\n- 床の材質によって、それぞれの手順でダニを退治しましょう。\n\n**畳の対策**\n- ダニ退治機能つきの電気掃除機で畳の畳面でいないに吸い取ったあと、畳の下に防ダニシートを敷きます。\n- プラスチック材を使用した新畳に取り替えます。\n\n'},
#   {'id': '79',
#    'text': '# Item 11\n## content\nこの資料は、カビ対策と塩害対策についての説明です。カビの防止対策として、適度な温度（20〜30℃）と湿度（70〜90％）、ホコリや髪の毛の除去が重要であると述べられています。特に押し入れは湿気がたまりやすいので注意が必要です。\n\n**入浴直後の対策**\n1. 浴室全体に熱めのシャワーをかけて、浴槽や壁の汚れを流します。\n2. 乾いた布で水滴を拭き取り、早く乾燥させます。\n3. 換気扇を回し、湿気を外に出します。\n\n**押し入れの対策**\n- 湿気の多い梅雨時には、ふすまを開けて扇風機で風を送り込み、換気します。\n- 通気の悪い押し入れには、押し入れ用のすのこを敷き、壁と物の間に隙間を作ります。\n- 押し入れ床の敷物には、防カビ効果のあるシートを使用します。\n\n**畳・掘ごたつの対策**\n- 梅雨など湿度の高い季節には、窓を閉め切って出かけると、帰宅した時に畳の表面がベタついていることがあります。これを放っておくと、表面にヌメリが出て、カビが生えやすくなります。時々フタを開けて換気を行います。\n\n'},
#   {'id': '45',
#    'text': '# Item 112\n## content\nこの画像は「お掃除道具の上手な使いこなし術」というタイトルのページで、ぞうきんを使った掃除方法について説明しています。\n\n### ぞうきんで汚れを拭き取る\n- **カラ拭き**: ほこりや水の跡を拭き取る方法。水を吸い込む素材のぞうきんを使い、強くこすらずに優しく拭きます。\n- **水拭き**: ぞうきんに水を含ませて拭く方法。完全に水が出なくなるまで絞ったものが最適です。使用後はバケツでゆすがず、蛇口でゆすぐと洗濯機での洗いが楽になります。\n\n### 洗剤拭き\n- **洗剤を使う方法**: かた絞りのぞうきんに洗剤を直接スプレーすることで、汚れの程度に応じた洗剤量の加減ができます。洗剤拭きのあとは必ず水拭きをして洗剤を拭き取ります。\n\n### 脱水拭き\n- **脱水機で水気を切る方法**: ぞうきんを生乾きの状態にして拭きます。水気を残さずに拭けるため、木材の掃除にも適しています。\n\n### 汚れを落とす\n- **サッシブラシ**: サッシの溝をサッシブラシで汚れをかき出してから掃除機で吸い取ります。\n\n### 快適情報\n- **便利な脱水拭き**: 脱水機で水気を切ったぞうきんは、拭いた後にぞうきんに水気を与えることができ、水気を与える場所にも使えます。\n\n'},
#   {'id': '1',
#    'text': '# Item 64\n## content\n### 浴室のお手入れ方法\n\n#### 毎日のお手入れの基本\n基本はシャワー＋スポンジ・雑巾で時間をかけずにお手入れします。\n\n1. **少し熱めのシャワーをかけて汚れを洗い流します。**\n   - 床から1mの高さまでは特に汚れがつきやすいので念入りに洗います。\n   - ドアには直接水をかけないでください。水がドアの外へ飛び散ることがあります。\n\n2. **こびりついた汚れはスポンジでやさしくこすり落とします。**\n\n3. **水のシャワーをかけて浴室内の温度を常温程度に下げます。**\n\n4. **残った水分をふき取り、窓を開けるか換気扇を回します。**\n   - 十分に換気してください。\n\n#### 浴室の床のお手入れの仕方\n\n- **浴室床の汚れ（石灰汚れ・カルシウム・石鹸カス）**\n  - クエン酸を使用。\n  - 床を濡らし、クエン酸をふりかけて30分置きます。\n  - 重曹をふりかけて、先割れ加工の浴室用ブラシでこすります。\n  - ※重曹をふりかけると、発砲しますが中性になるときの反応です。\n\n| BEFORE | AFTER |\n|--------|-------|\n| ![Before Image](before.jpg) | ![After Image](after.jpg) |\n\n- **石鹸カス・カルシウム・ミネラル**\n\n'},
#   {'id': '57',
#    'text': '# Item 103\n## content\nこの画像は、抜け止めの取り付け方法についての説明です。\\n\\n### 抜け止めの取りつけ方\\n- **抜け止めAタイプの場合**\\n  1. 抜け止めを奥まで差し込む。\\n  2. 抜け止めをスライドさせて、サポート材のスリットに奥まで差し込み、ロックします。\\n\\n- **抜け止めBタイプの場合**\\n  1. 棚板アームに抜け止めをかぶせます。\\n  2. 抜け止めを、サポート材のスリットに奥まで差し込み、ロックします。\\n\\n### 注意事項\\n- **警告**\\n  - ケガや事故の原因になります。\\n  - 棚板やハンガーバーにぶら下がったりしないでください。\\n  - 棚板の移動、設置の際は、記載した手順に従い、アームがサポート材にしっかりはまっていることを確認してから、ご使用ください。\n\n'}]}
